# %%
# %load_ext autoreload 
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from skyjo_main import Deck, Player, Game

# %%
A = Player("A")
B = Player("B")
C = Player("C")

# %%
players = [A,B,C]
deck = Deck()

# %%
players.index(B)
# Out:
# 1

# %%
game = Game(players, deck)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 game = Game(players, deck)
#
# File ~/Library/CloudStorage/Dropbox/project/skyjo/skyjo_main.py:100, in Game.__init__(self, players, deck)
#      98 self.legal_draw = ["draw_from_bin", "draw_from_deck"]
#      99 self.legal_action = ["replace_card", "discover_card"]
# --> 100 self._distribute_cards()
#
# File ~/Library/CloudStorage/Dropbox/project/skyjo/skyjo_main.py:109, in Game._distribute_cards(self)
#     107 for row in range(0,3):
#     108     for col in range(0,4):
# --> 109         card = self.deck.pop_random_card()
#     110         p._cards[row][col] = card
#
# File ~/Library/CloudStorage/Dropbox/project/skyjo/skyjo_main.py:52, in Deck.pop_random_card(self)
#      50 def pop_random_card(self):
#      51     index = np.random.randint(0, len(self.deck)+1)
# ---> 52     return self.deck[index]
# ...

# %%
game.deck
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 game.deck
#
# NameError: name 'game' is not defined

# %%
cartes.shuffle()

# %%
import numpy as np

# %%
a = (["x",1,2,3,4],["x","x","x", "x"],["x",1,2,3,4])

# %%
[["x", "3", "x", "x"]]*4
# Out:
# [['x', 'x', 'x', 'x'],
#  ['x', 'x', 'x', 'x'],
#  ['x', 'x', 'x', 'x'],
#  ['x', 'x', 'x', 'x']]

# %%
row = [1,2,"x", "x"]

# %%
sum([i for i in row if isinstance(i, int)])
# Out:
# 3

# %%
a
# Out:
# ['x', 1, 2, 3, 4]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 [i for i in j for j in a]
#
# NameError: name 'j' is not defined

# %%
int(a[2])
# Out:
# 2

# %%
isinstance(a[2], int)
# Out:
# False
